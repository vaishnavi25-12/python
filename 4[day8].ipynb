# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishnavi25-12/python/blob/main/4%5Bday8%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# String Compression

# %%
a = "AAACCCBAABB"
result = ""
count = 1
for i in range(len(a)):
    if i < len(a) - 1 and a[i] == a[i+1]:
        count += 1
    else:
        result += a[i] + str(count)
        count = 1
print(result)
# Out:
# A3C3B1A2B2

# %% [markdown]
# 1. class=container[methods,variable]
# 2. object=member of class
# 3. recursion:
# * fns calling itself
# * base condition:exit of function
# * arg:should be different
# * back tracking: even  if there is one statemnet after recursive call
# * nexted recursion(more than one)
# * top down approach

# %%
"""
def vaishnavi(a):
  a==1:
  return 1
  else: return a * (vaishnavi(a-1)
vaishnavi(a)
a=6
x=vaishnavi(a)
print(x)"""
def flower(a):
    if a == 4:
        return
    print(a+10, end=" ")
    flower(a+1)
    print(a, end=" ")
flower(1)

# %%
def raju(a):
    if a==1:
        return
    a-=1
    raju(a)
    print("hi")
    raju(a)
raju(5)
# Out:
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi
# hi

# %%
def raju(a):
    if a == 4:
        return 1
    B = raju(a + 1)
    print("hi")
    return B + 2
result = raju(1)
print("Result:", result)
# Out:
# hi
# hi
# hi
# Result: 7

# %%
import qrcode

qr = qrcode.QRCode()

text = "mxkmdlkd;l;lsdkoeidkijfijeiofj"

qr.add_data(text)
qr.make(fit=True)

img = qr.make_image(fill_color="black", back_color="white")

img.save("vaishu.png")

print("successful")

# %%
import qrcode
qr=qrcode.QRCode()
a="hrfhhkjdfk"
qr.add_data(a)
qr.make(fit=True)
res=qr.make-image(fill_color="black",back_color="white")
res.save("jdhj.png")
print("created njfh")

# %% [markdown]
# oops
# 1. var(4types)
#    1. local (has scope only in particular method)(local)
#    2. instance(global)(each and every object holds unique valuesex:cgpa)
#    3. class(global)(every object holds same value)
#    4. complete (global)()
# 2. class : methods and variable(container)
# 3. obj :member of class
# * inside or outside class methods and variables should be used by object name or class name

# %%
class abc:
    num=100
    def set_dim(self,a,b):
        self.total=a+b+abc.num
        self.display()
    def display(self):
        print("addition is:",self.total)

a=abc()
b=abc()
a.set_dim(20,30)
b.set_dim(30,50)
# Out:
# addition is: 150
# addition is: 180

# %%
x="vaishu"
class ACE:
    def set_dim(self,a,b,c,d):
        self.total=a+b+c
        self.name=d
    def display(self):
        print("1. name= ",self.name)
        print("2. mark= ",self.total)
        print("3. country:",x)
class BVRIT:
    def set_dim(self,a,b,c,d):
        self.total=a+b+c
        self.name=d
    def display(self):
        print("1. name= ",self.name)
        print("2. mark= ",self.total)
        print("3. country:",x)
a=ACE()
a.set_dim(20,30,40,"vaishu")
a.display()
b=BVRIT()
b.set_dim(30,50,60,"bhavi")
b.display()
