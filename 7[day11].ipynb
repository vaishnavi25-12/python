# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishnavi25-12/python/blob/main/7%5Bday11%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
overs=np.arange(1,11)
scores=[2,4,7,1,12,8,5,3,9,10]
plt.bar(overs,scores,color="green")
plt.title("INDIA SCORE BASED ON OVERS")
plt.xlabel("overs from 10")
plt.ylabel("runs by overs")
plt.xticks(overs)
plt.grid(axis="y",linestyle="-")
plt.show()

# %% [markdown]
# percentile tells you how a value compares with other values in a dataset.
#
# Simple Meaning
#
# If you are in the:
#
# 90th percentile
# → you scored better than 90% of people
# 50th percentile
# → you are exactly in the middle
# 25th percentile
# → you scored better than 25% of people

# %%
import numpy as np
a=[10,20,30,40,50,60]
res=np.percentile(a,50)
print(res)
# Out:
# 35.0

# %%
from scipy import stats
a=[10,20,30,40,50,60]
res=stats.percentileofscore(a,50)
print(res)
# Out:
# 83.33333333333334

# %%
from tabulate import tabulate
title=[ "Name","age","dept"]
data=[["raj","19","cse"],
["vaui","16","ece"],
["jid","23","fed"]]
res=tabulate(data,headers=title,tablefmt="pretty")
print(res)
# Out:
# +------+-----+------+
# | Name | age | dept |
# +------+-----+------+
# | raj  | 19  | cse  |
# | vaui | 16  | ece  |
# | jid  | 23  | fed  |
# +------+-----+------+

# %%
a = open("TVK.txt", "w")

n1 = int(input("Enter first number: "))
n2 = int(input("Enter second number: "))

s = n1 + n2

a.write(str(n1))
a.write(str(n2))
a.write(str(s))

print("OK")

a.close()
# Out:
# Enter first number: 5
# Enter second number: 6
# OK

# %%
from tabulate import tabulate
title=[ "Name","age","dept"]
data=[["raj","19","cse"],
["vaui","16","ece"],
["jid","23","fed"]]
res=tabulate(data,headers=title,tablefmt="pretty")
with open("vaish.txt",'w') as file:
  file.write(res)
print("job done")
# Out:
# job done

# %%
a=open("TVK.txt",'r')
c=a.readlines()
while c:
  print(c)
  c=a.readlines()
a.close()
# Out:
# ['5611']

# %% [markdown]
# STACK:
# * FILO
# * recursion principle
# * back button in browser
# * undo (ctrl Z)
# QUEUE:
# * LILO,FIFO
# * complex algorithm

# %% [markdown]
# IMPLEMENTATION OF STACK:

# %%
class stack:
  def __init__ (self):
    self.l=[]
  def push(self,a):
    self.l.append(a)
  def pop(self):
    if not self.l:
        print("Stack is empty!")
        return
    self.l.pop()
  def display(self):
    if not self.l:
        print("Stack is empty")
        return
    b="->".join(map(str,self.l))
    print(b)
  def peek(self):
    if not self.l:
        print("Stack is empty!")
        return
    print(self.l[-1])
s=stack()
s.push(100)
s.push(30)
s.push(56)
s.display()
s.pop()
s.display()
s.peek()
# Out:
# 100->30->56
# 100->30
# 30

# %% [markdown]
# valid paranthesis , solving mathematical expreesion:leetcode

# %%
a=[2,3,4,5]
b="".join(map(str,a))
print(b)
# Out:
# 2345

# %% [markdown]
# * BST
# * AVL Tress (balance factor is atmost 1)self balancing bst
# * red-black tree
# * b-tree
# traversal special
# 1. pre-root,left,right
# 2. post-left,right,root
# 3. in-left ,root,right

# %%
""""rotation"""
node x=y.left
node t2=x.right
x.right=y;
y.left=t2;
return x
