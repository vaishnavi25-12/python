# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishnavi25-12/python/blob/main/2%5BDay6%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=1
for i in range(2,5):
    a=a+i
    for j in range(i):
       a=a+j
       print(str(a),end=" ")
    print()
print(a)

# %% [markdown]
# functions: block of code,built in,def function
# advantages: reusability,readability,integrstion
# types:
# 1.without r and without a
# 2.without r and with a
# 3.with r and without a
# 4.with r and with a
# -----------
# function calling(1st):
# def a1(): #must contain return and print statement
# print(20+40)
# def a2(a,b):
# print(a+b)
# def a3():
# a=10
# b=34
# return a+b
# def a4(a,b):
# return a+b
#
#
# a1()
# a2(10,20)
#  a3()# returning something use res
# a4(90,60)

# %% [markdown]
# menu driven program
# 1.square
# 2.rectangle
# 3.circle
# 4.triangle
# 5.exit
# enter ur choice: 2
# enter length:
# enter breadth:
# choice: 1
# enter side: 20
# area: 400
# CONSTRAINT: use

# %%
import math
def square():
    s=int(input("enter side:"))
    area=s*s
    print("Area",area)
def rectangle(l,b):
    area=2*l*b
    print("Area",area)
def circle():
    r=int(input("enter the radius"))
    return 3.14*r*r
def triangle(b,h):
    return 0.5*b*h
while True:
    print("\n MENU")
    print("1.Square")
    print("2. rectangle")
    print("3. Trinagle")
    print("4. Circle")
    print("5.Exit")
    choice=int(input("enter ur choice:"))
    if choice==1:
        square()
    elif choice==2:
        l=float(input("enter length:"))
        b=float(input("enter breadth"))
        rectangle(l,b)
    elif choice==3:
        result=circle()
        print("Area",result)
    elif choice==4:
        base=float(input("enter base:"))
        height=float(input("enter height:"))
        result=triangle(b,h)
        print("Area",result)
    elif choice==5:
        print("exiting..")
        brerak
    else:
        print("invalid choice")

# %%
def prime(n):
  if n<=1:
    return False
  else:
    for i in range(2,n):
        if n%i==0:
            return False
    return True
def sod(n):
    d=[int(i)for i in str(n)]
    return sum(d)
def every(n):
    for i in range(3):
        d=n%10
        n=n//10
        if  not prime(d):
            return False
    return True
for i in range(100,1000):
  if prime(i) and prime(sod(i)) and every(i):
    print(i,end=" ")
# Out:
# 223 227 337 353 373 557 577 733 757 773

# %%
a=int(input("enter any number:"))
for i in range(5,a):
  for j in range(4,i):
    for k in range(3,j):
      if k*k+ j*j == i*i:
                print(k,j,i)
# Out:
# enter any number:20
# 3 4 5
# 6 8 10
# 5 12 13
# 9 12 15
# 8 15 17
