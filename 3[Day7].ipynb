# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishnavi25-12/python/blob/main/3%5BDay7%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Subject Analysis: type conversion ,merge &opertaors

# %%
Math = ['Tom','Jerry','Spike','Tyke']
Political = ['Jerry','Spike','Butch','Nibbles']
Science = ['Spike','Tyke','Nibbles','Quacker']


M = set(Math)
P = set(Political)
S = set(Science)


all_three = M & P & S


two_subjects = (M & P) | (P & S) | (M & S)
two_subjects = two_subjects - all_three


all_names = M | P | S
one_subject = all_names - two_subjects - all_three

print("Only one subject =", list(one_subject))
print("Exactly two subjects =", list(two_subjects))
print("All subjects =", list(all_three))
# Out:
# Only one subject = ['Butch', 'Tom', 'Quacker']
# Exactly two subjects = ['Tyke', 'Jerry', 'Nibbles']
# All subjects = ['Spike']

# %% [markdown]
# monkey puzzle:odd /even usaing var i-"while"

# %%
X = 21
Y = 5
Z = 3

time = 0
ht = 0
i = 1

while ht < X:


    if i % 2 == 1:
        ht = ht + Y
        time += 1


        if ht >= X:
            break


    else:
        ht = ht - Z
        time += 1

    i += 1

print(time)
# Out:
# 17

# %% [markdown]
# leap year- merging operators

# %%
a = 2100

if (a % 400 == 0) or (a % 4 == 0 and a % 100 != 0):
    print("yes")
else:
    print("no")
# Out:
# no

# %% [markdown]
# fizz buzz- condition priority

# %%
n = int(input("Enter n: "))
answer = []

for i in range(1, n + 1):
    if i % 3 == 0 and i % 5 == 0:
        answer.append("FizzBuzz")
    elif i % 3 == 0:
        answer.append("Fizz")
    elif i % 5 == 0:
        answer.append("Buzz")
    else:
        answer.append(str(i))

print(answer)
# Out:
# Enter n: 5
# ['1', '2', 'Fizz', '4', 'Buzz']
